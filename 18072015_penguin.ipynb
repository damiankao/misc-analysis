# %%
import gzip, os, sys
#import custom functions for displaying tables, bash commands
sys.path.append(os.path.abspath("/home/damian/"))
from dk_ipython import *
from IPython.display import HTML
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss
import scipy as sp
from collections import defaultdict

# %matplotlib inline
HTML(addToggle())
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
#
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# ## SNP analysis of penguin population
#
# Reads were gathered from 180 individuals. According to the barcoding of libraries, there are 116 'EP' (emperor penguin) individuals and 64 'KP' (king penguin) individuals.
#
# A total of 8 pair-end libraries were generated with 3 paired .fastq (6 total) each.
#
# Individual barcode sequences seems to be inline with the read sequences instead of in the header. Info for de-multiplexing the reads is in the .pools files describing the barcode sequence and invidual IDs.
#
# The following python script was used to de-multiplex the reads:

# %%
HTML(textarea('de-multiplex script','''import sys,gzip

prefix = sys.argv[1]
barcodes = dict([(x.strip().split()[1], x.strip().split()[0]) for x in open(sys.argv[2],'r')])

outLibs = {}
libCounts = {}
discarded = 0
total = 0
for bc, lib in barcodes.items():
        outLibs[lib + "1"] = open(lib + '.' + prefix + '_1.fastq','w')
        outLibs[lib + "2"] = open(lib + '.' + prefix + '_2.fastq','w')
        libCounts[lib] = 0

fileA = gzip.open(sys.argv[3],'r')
fileB = gzip.open(sys.argv[4],'r')

def getEntry(stream):
        seq = ''
        header = ''
        for line in stream:
                header = line.strip()
                break

        if header != '':
                seq = stream.next().strip()
                stream.next()
                qual = stream.next().strip()
                return [header,seq,'+',qual]
        else:
                return -1

while 1:
        entryA = getEntry(fileA)
        entryB = getEntry(fileB)
        if entryA == -1:
                break

        pos_A = -1
        type_A = 'NA'
        for bc in barcodes.keys():
                pos_A = entryA[1].find(bc)
                if pos_A != -1:
                        type_A = barcodes[bc]
                        break

        if pos_A != -1 and pos_A < 5:
                entryA[1] = entryA[1][pos_A + 8:]
                entryA[3] = entryA[4][pos_A + 8:]
                outLibs[type_A + '1'].write('\\n'.join(entryA) + '\\n')
                outLibs[type_A + '2'].write('\\n'.join(entryB) + '\\n')
                libCounts[type_A] += 1
        else:
                discarded += 1

        total += 1

print '\\n'.join([k + '\\t' + str(v) for k,v in libCounts.items()])
print 'discarded\t' + str(discarded)
print 'total\t' + str(total)
'''))
# Out:
# <b>de-multiplex script</b>:<br>
# <textarea style="width: 800px; height:200px">
# import sys,gzip
#
# prefix = sys.argv[1]
# barcodes = dict([(x.strip().split()[1], x.strip().split()[0]) for x in open(sys.argv[2],'r')])
#
# outLibs = {}
# libCounts = {}
# discarded = 0
# total = 0
# for bc, lib in barcodes.items():
#         outLibs[lib + "1"] = open(lib + '.' + prefix + '_1.fastq','w')
#         outLibs[lib + "2"] = open(lib + '.' + prefix + '_2.fastq','w')
#         libCounts[lib] = 0
#
# fileA = gzip.open(sys.argv[3],'r')
# fileB = gzip.open(sys.argv[4],'r')
#
# def getEntry(stream):
#         seq = ''
#         header = ''
#         for line in stream:
#                 header = line.strip()
#                 break
#
#         if header != '':
#                 seq = stream.next().strip()
#                 stream.next()
#                 qual = stream.next().strip()
#                 return [header,seq,'+',qual]
#         else:
#                 return -1
#
# while 1:
#         entryA = getEntry(fileA)
#         entryB = getEntry(fileB)
#         if entryA == -1:
#                 break
#
#         pos_A = -1
#         type_A = 'NA'
#         for bc in barcodes.keys():
#                 pos_A = entryA[1].find(bc)
#                 if pos_A != -1:
#                         type_A = barcodes[bc]
#                         break
#
#         if pos_A != -1 and pos_A < 5:
#                 entryA[1] = entryA[1][pos_A + 8:]
#                 entryA[3] = entryA[4][pos_A + 8:]
#                 outLibs[type_A + '1'].write('\n'.join(entryA) + '\n')
#                 outLibs[type_A + '2'].write('\n'.join(entryB) + '\n')
#                 libCounts[type_A] += 1
#         else:
#                 discarded += 1
#
#         total += 1
#
# print '\n'.join([k + '\t' + str(v) for k,v in libCounts.items()])
# print 'discarded	' + str(discarded)
# print 'total	' + str(total)
#
# </textarea>

# %% [markdown]
# The script takes in a pair of .fastq files and look for exact matches to the barcode. The start of the barcode sequence must be found within the first 5 base-pairs of the forward read to be considered. Anything that doesn't match is discarded. Use the script by:
#
#     python deplex.py <prefix> <barcode file> <forward fastq> <reverse fastq> > deplex.log
#
# Not sure if this is the optimal method of de-multiplexing reads. The Stacks package can also perform this. It might do something more sophisticated like including reads with barcode off by a base or two.
#
# Are there any read processing that needs to be done at the restriction site?

# %%
prefix = '/data/ngs/penguin/'

# %% [markdown]
# ### De-multiplex results

# %%
metas = [f for f in os.listdir(prefix) if f.split('.')[-1] == 'meta']

inds = defaultdict(int)
total = 0
discarded = 0
for meta in metas:
    inFile = open(prefix + meta)
    for line in inFile:
        cols = line.strip().split()
        if cols[0] == 'total':
            total += int(cols[1])
        elif cols[0] == 'discarded':
            discarded += int(cols[1])
        else:
            inds[cols[0]] += int(cols[1])
        
    inFile.close()

# %%
print 'Total number of pairs from all libraries:', commas(total)
print 'Total number of pairs discarded (no exact barcode matches within first 5 base pairs):', commas(discarded)
print 'Number of pairs left over:', commas(total - discarded), '(' + str(100 * (total - discarded) / float(total)) + '%)'
print
indTable = inds.items()
indTable.sort(key = lambda x : x[1], reverse = True)
indTable = ListTable([[x[0],commas(x[1])] for x in indTable])
indTable.insert(0,['individual ID','number of pairs assigned'])
indTable
# Out:
# Total number of pairs from all libraries: 1,320,770,195
# Total number of pairs discarded (no exact barcode matches within first 5 base pairs): 230,249,538
# Number of pairs left over: 1,090,520,657 (82.5670249926%)
# [['individual ID', 'number of pairs assigned'],
#  ['EPDDU014', '27,454,328'],
#  ['KPMQ044', '25,424,951'],
#  ['EPWIS012', '18,568,504'],
#  ['EPDDU007', '15,753,698'],
#  ['KPMQ037', '15,447,441'],
#  ['EPWIS011', '14,853,580'],
#  ['EPAUS011', '14,280,761'],
#  ['EPWIS021', '14,218,684'],
#  ['KPMQ049', '13,310,375'],
#  ['KPMQ016', '13,102,300'],
#  ['EPDDU012', '12,277,497'],
#  ['EPDDU001', '12,125,344'],
#  ['EPDDU009', '11,565,352'],
#  ['KPMQ017', '11,229,116'],
#  ['KPUVF012', '11,049,061'],
#  ['EPCWS003', '10,864,608'],
#  ['KPFORT009', '10,248,922'],
#  ['EPFLD023', '10,220,826'],
#  ['KPMQ023', '10,185,960'],
#  ['EPDDU004', '10,025,165'],
#  ['EPFLD022', '9,655,107'],
#  ['KPFORT005', '9,522,565'],
#  ['EPDDU027', '9,492,086'],
#  ['EPDDU008', '9,400,662'],
#  ['KPVP020', '9,292,592'],
#  ['KPUVF002', '9,196,933'],
#  ['KPMQ004', '8,999,663'],
#  ['EPWIS015', '8,890,572'],
#  ['EPFLD011', '8,871,236'],
#  ['EPDDU002', '8,715,668'],
#  ['KPFORT006', '8,629,856'],
#  ['EPWIS025', '8,548,666'],
#  ['KPFORT012', '8,531,858'],
#  ['EPFLD020', '8,452,143'],
#  ['KPUVM001', '8,374,569'],
#  ['KPMQ018', '8,120,808'],
#  ['EPDDU105', '7,949,576'],
#  ['EPWIS024', '7,926,996'],
#  ['KPFORT014', '7,916,536'],
#  ['KPFORT013', '7,814,681'],
#  ['EPFLD010', '7,601,532'],
#  ['EPDDU028', '7,529,051'],
#  ['KPUVM006', '7,523,529'],
#  ['EPAUS001', '7,437,515'],
#  ['EPFLD026', '7,328,336'],
#  ['EPAMB008', '7,300,174'],
#  ['EPWIS014', '7,286,107'],
#  ['KPFORT008', '7,139,491'],
#  ['KPMQ036', '7,107,925'],
#  ['KPVP010', '6,945,171'],
#  ['KPUVM019', '6,874,845'],
#  ['KPMQ025', '6,846,788'],
#  ['EPWIS010', '6,743,570'],
#  ['EPDDU005', '6,558,164'],
#  ['EPGOU036', '6,557,658'],
#  ['KPUVF001', '6,530,590'],
#  ['KPUVF005', '6,510,451'],
#  ['KPMQ032', '6,399,011'],
#  ['KPFORT007', '6,395,950'],
#  ['KPVP012', '6,366,177'],
#  ['EPDDU030', '6,320,381'],
#  ['EPCWB005', '6,287,340'],
#  ['KPFORT015', '6,276,293'],
#  ['KPUVF003', '6,223,266'],
#  ['KPUVM012', '6,221,606'],
#  ['KPUVF013', '6,212,344'],
#  ['KPUVM009', '6,184,888'],
#  ['KPVP011', '5,942,988'],
#  ['KPFORT001', '5,915,028'],
#  ['EPFLD002', '5,913,712'],
#  ['KPFORT024', '5,884,989'],
#  ['KPVP004', '5,823,001'],
#  ['EPCWA003', '5,820,019'],
#  ['EPFLD012', '5,805,438'],
#  ['KPUVM005', '5,746,548'],
#  ['EPFLD027', '5,732,214'],
#  ['EPAUS024', '5,720,720'],
#  ['EPAMB001', '5,662,726'],
#  ['EPFLD024', '5,656,418'],
#  ['KPUVM010', '5,644,232'],
#  ['EPGOU037', '5,637,098'],
#  ['KPUVF006', '5,606,360'],
#  ['EPAMB022', '5,545,998'],
#  ['EPWIS002', '5,501,324'],
#  ['KPVP019', '5,488,758'],
#  ['KPMQ043', '5,482,517'],
#  ['EPDDU029', '5,451,627'],
#  ['EPAMB018', '5,440,945'],
#  ['EPAMB002', '5,429,658'],
#  ['EPFLD016', '5,424,100'],
#  ['KPVP013', '5,297,045'],
#  ['KPMQ021', '5,264,423'],
#  ['EPWIS008', '5,199,573'],
#  ['EPCWS002', '5,173,222'],
#  ['EPAUS023', '5,156,050'],
#  ['EPCWA002', '5,079,869'],
#  ['KPUVF010', '5,055,376'],
#  ['KPUVF011', '5,044,496'],
#  ['EPAUS020', '4,948,755'],
#  ['EPWIS013', '4,934,354'],
#  ['KPVP005', '4,910,077'],
#  ['KPVP003', '4,882,692'],
#  ['EPFLD004', '4,790,605'],
#  ['KPVP001', '4,784,559'],
#  ['EPAUS004', '4,773,115'],
#  ['EPAMB007', '4,766,394'],
#  ['EPGOU033', '4,749,831'],
#  ['EPAMB006', '4,666,094'],
#  ['KPFORT011', '4,567,441'],
#  ['EPGOU030', '4,557,366'],
#  ['KPVP017', '4,535,868'],
#  ['EPCWB004', '4,457,306'],
#  ['KPFORT010', '4,422,327'],
#  ['EPAUS022', '4,411,586'],
#  ['EPAMB016', '4,402,566'],
#  ['EPCRD001', '4,335,292'],
#  ['EPGOU034', '4,291,889'],
#  ['KPMQ034', '4,283,046'],
#  ['EPFLD001', '4,214,128'],
#  ['KPFORT016', '4,192,855'],
#  ['KPMQ042', '4,179,579'],
#  ['EPFLD014', '4,142,558'],
#  ['KPFORT023', '4,135,246'],
#  ['EPAUS027', '4,048,755'],
#  ['KPMQ020', '3,999,789'],
#  ['EPCRD007', '3,962,724'],
#  ['EPFLD028', '3,950,363'],
#  ['EPAUS010', '3,944,460'],
#  ['EPDDU010', '3,944,090'],
#  ['EPWIS007', '3,934,888'],
#  ['EPFLD015', '3,896,308'],
#  ['EPGOU045', '3,869,974'],
#  ['KPFORT019', '3,851,758'],
#  ['EPCWA006', '3,840,489'],
#  ['EPAUS025', '3,812,431'],
#  ['KPVP018', '3,763,554'],
#  ['EPGOU040', '3,756,852'],
#  ['EPAUS018', '3,649,298'],
#  ['EPAMB019', '3,624,939'],
#  ['EPAMB014', '3,612,803'],
#  ['EPGOU035', '3,602,617'],
#  ['EPWIS009', '3,488,508'],
#  ['EPCRD002', '3,446,453'],
#  ['EPGOU043', '3,436,384'],
#  ['EPGOU044', '3,422,592'],
#  ['EPGOU031', '3,414,121'],
#  ['EPCRD004', '3,386,823'],
#  ['EPAMB013', '3,381,744'],
#  ['EPGOU041', '3,359,506'],
#  ['EPAMB029', '3,328,405'],
#  ['EPGOU038', '3,208,600'],
#  ['KPVP009', '3,192,619'],
#  ['EPCWC014', '3,105,151'],
#  ['EPCRD019', '3,095,907'],
#  ['EPAMB010', '3,066,763'],
#  ['EPAMB020', '3,056,387'],
#  ['EPGOU039', '3,001,854'],
#  ['EPGOU032', '2,963,418'],
#  ['KPVP007', '2,941,645'],
#  ['KPVP008', '2,898,232'],
#  ['EPAUS017', '2,885,300'],
#  ['KPVP006', '2,828,919'],
#  ['EPAUS019', '2,760,249'],
#  ['EPAMB012', '2,654,424'],
#  ['EPCWA007', '2,634,728'],
#  ['EPCRD008', '2,620,501'],
#  ['EPWIS001', '2,553,506'],
#  ['EPAUS016', '2,431,101'],
#  ['EPAMB030', '2,328,322'],
#  ['EPCWC050', '2,153,158'],
#  ['EPAUS002', '2,130,979'],
#  ['EPADF001', '2,127,876'],
#  ['EPCRD020', '1,879,454'],
#  ['EPCWB031', '1,821,114'],
#  ['EPCRD017', '1,547,799'],
#  ['EPCRD016', '593,282'],
#  ['EPADC001', '89,016'],
#  ['EPWIS026', '64,616'],
#  ['EPCRD006', '51,905'],
#  ['EPAUS015', '3,804']]

# %%
print 'Pairs per individual (10 million). Multiple by 2 for reads.'
pd.Series(inds.values()).hist(bins=50, figsize=[10,4])
# Out:
# Pairs per individual (10 million). Multiple by 2 for reads.

# %% [markdown]
# ### Trimming reads
#
# Reads for each individual were trimmed for quality and possible adapter sequence that wasn't properly removed. Trimmomatic 0.32 was used for trimming with the following command:
#
#     java -jar trimmomatic-0.32.jar PE -threads 6 -phred33 1.fastq 2.fastq 1.p.fastq 1.up.fastq 2.p.fastq 2.up.fastq LEADING:20 TRAILING:20 MINLEN:50 ILLUMINACLIP:adapters.fa:2:30:12:1:false TOPHRED33

# %%
trimLog = open(prefix + 'trim.err')
statTable = ListTable()
lib = ''
stat = []
for line in trimLog:
    if line.find('TrimmomaticPE: Started') != -1:
        if lib != '':
            statTable.append([lib,commas(stat[0]),commas(stat[1]),str(100 * stat[1] / float(stat[0]))])
        meta = line.strip().split()
        lib = meta[7].split('/')[-1].split('_')[0]
        stat = []
    elif line.find('Input Read Pairs:') != -1:
        meta = line.strip().split()
        stat.append(int(meta[3]))
        stat.append(int(meta[6]))
statTable.sort(key = lambda x : int(''.join(x[1].split(','))), reverse = True)
statTable.insert(0,['Individual','Total reads','Reads kept','% reads kept'])

# %%
statTable
# Out:
# [['Individual', 'Total reads', 'Reads kept', '% reads kept'],
#  ['EPDDU014', '27,454,328', '27,229,936', '99.182671672'],
#  ['KPMQ044', '25,424,951', '25,128,884', '98.8355257794'],
#  ['EPWIS012', '18,568,504', '18,442,498', '99.3213992899'],
#  ['EPDDU007', '15,753,698', '15,620,351', '99.1535511218'],
#  ['KPMQ037', '15,447,441', '15,275,373', '98.8861067668'],
#  ['EPWIS011', '14,853,580', '14,754,051', '99.3299325819'],
#  ['EPWIS021', '14,218,684', '14,116,168', '99.279005005'],
#  ['KPMQ049', '13,310,375', '13,189,715', '99.0934891015'],
#  ['KPMQ016', '13,102,300', '12,972,744', '99.0111965075'],
#  ['EPDDU012', '12,277,497', '12,164,731', '99.081522887'],
#  ['EPDDU001', '12,125,344', '12,067,731', '99.5248547175'],
#  ['EPDDU009', '11,565,352', '11,477,898', '99.2438275982'],
#  ['KPMQ017', '11,229,116', '11,141,574', '99.2204016772'],
#  ['KPUVF012', '11,049,061', '11,001,816', '99.5724071032'],
#  ['EPCWS003', '10,864,608', '10,810,569', '99.5026143603'],
#  ['KPFORT009', '10,248,922', '10,209,717', '99.6174719644'],
#  ['EPFLD023', '10,220,826', '10,151,230', '99.31907656'],
#  ['KPMQ023', '10,185,960', '10,034,353', '98.5116081351'],
#  ['EPDDU004', '10,025,165', '9,984,390', '99.5932735272'],
#  ['EPFLD022', '9,655,107', '9,585,682', '99.2809504856'],
#  ['KPFORT005', '9,522,565', '9,485,557', '99.6113652151'],
#  ['EPDDU027', '9,492,086', '9,422,243', '99.2641975642'],
#  ['EPDDU008', '9,400,662', '9,331,106', '99.2600946614'],
#  ['KPVP020', '9,292,592', '9,256,409', '99.6106253239'],
#  ['KPUVF002', '9,196,933', '9,159,083', '99.5884497582'],
#  ['KPMQ004', '8,999,663', '8,912,026', '99.0262190929'],
#  ['EPWIS015', '8,890,572', '8,831,195', '99.3321352102'],
#  ['EPFLD011', '8,871,236', '8,808,035', '99.2875739074'],
#  ['EPDDU002', '8,715,668', '8,679,054', '99.5799059808'],
#  ['KPFORT006', '8,629,856', '8,595,402', '99.6007581123'],
#  ['EPWIS025', '8,548,666', '8,486,251', '99.2698860852'],
#  ['KPFORT012', '8,531,858', '8,497,174', '99.5934765909'],
#  ['EPFLD020', '8,452,143', '8,393,124', '99.3017273844'],
#  ['KPUVM001', '8,374,569', '8,337,843', '99.5614580285'],
#  ['KPMQ018', '8,120,808', '7,971,446', '98.1607495215'],
#  ['EPDDU105', '7,949,576', '7,894,642', '99.3089694343'],
#  ['EPWIS024', '7,926,996', '7,874,731', '99.3406707913'],
#  ['KPFORT014', '7,916,536', '7,886,278', '99.6177873757'],
#  ['KPFORT013', '7,814,681', '7,785,096', '99.6214176881'],
#  ['EPFLD010', '7,601,532', '7,550,013', '99.3222550402'],
#  ['EPDDU028', '7,529,051', '7,473,963', '99.2683274426'],
#  ['KPUVM006', '7,523,529', '7,490,776', '99.5646590849'],
#  ['EPAUS001', '7,437,515', '7,397,381', '99.4603842816'],
#  ['EPFLD026', '7,328,336', '7,277,277', '99.3032661166'],
#  ['EPAMB008', '7,300,174', '7,266,591', '99.5399698692'],
#  ['EPWIS014', '7,286,107', '7,232,531', '99.2646827723'],
#  ['KPFORT008', '7,139,491', '7,111,858', '99.6129556015'],
#  ['KPMQ036', '7,107,925', '7,026,207', '98.8503255169'],
#  ['KPVP010', '6,945,171', '6,916,407', '99.5858417309'],
#  ['KPUVM019', '6,874,845', '6,843,384', '99.5423751372'],
#  ['KPMQ025', '6,846,788', '6,643,102', '97.0250867998'],
#  ['EPWIS010', '6,743,570', '6,698,004', '99.3243044856'],
#  ['EPDDU005', '6,558,164', '6,508,570', '99.2437822537'],
#  ['EPGOU036', '6,557,658', '6,513,867', '99.3322158612'],
#  ['KPUVF001', '6,530,590', '6,502,198', '99.5652460191'],
#  ['KPUVF005', '6,510,451', '6,480,461', '99.5393560293'],
#  ['KPMQ032', '6,399,011', '6,325,682', '98.854057291'],
#  ['KPFORT007', '6,395,950', '6,371,045', '99.610612966'],
#  ['KPVP012', '6,366,177', '6,339,893', '99.5871305495'],
#  ['EPDDU030', '6,320,381', '6,270,287', '99.2074211982'],
#  ['EPCWB005', '6,287,340', '6,255,273', '99.4899750928'],
#  ['KPFORT015', '6,276,293', '6,251,917', '99.611617877'],
#  ['KPUVF003', '6,223,266', '6,196,886', '99.5761068224'],
#  ['KPUVM012', '6,221,606', '6,193,676', '99.5510805409'],
#  ['KPUVF013', '6,212,344', '6,183,808', '99.5406564736'],
#  ['KPUVM009', '6,184,888', '6,150,558', '99.4449374023'],
#  ['KPVP011', '5,942,988', '5,918,493', '99.5878335948'],
#  ['KPFORT001', '5,915,028', '5,889,196', '99.5632818644'],
#  ['EPFLD002', '5,913,712', '5,871,442', '99.285220518'],
#  ['KPFORT024', '5,884,989', '5,860,643', '99.5863033899'],
#  ['KPVP004', '5,823,001', '5,781,511', '99.2874808024'],
#  ['EPCWA003', '5,820,019', '5,776,466', '99.2516691097'],
#  ['EPFLD012', '5,805,438', '5,761,936', '99.2506680805'],
#  ['KPUVM005', '5,746,548', '5,720,905', '99.5537668875'],
#  ['EPFLD027', '5,732,214', '5,693,627', '99.3268395074'],
#  ['EPAUS024', '5,720,720', '5,691,826', '99.4949237159'],
#  ['EPAMB001', '5,662,726', '5,637,545', '99.5553201762'],
#  ['EPFLD024', '5,656,418', '5,616,973', '99.3026505467'],
#  ['KPUVM010', '5,644,232', '5,615,197', '99.4855810321'],
#  ['EPGOU037', '5,637,098', '5,598,660', '99.3181243257'],
#  ['KPUVF006', '5,606,360', '5,583,019', '99.5836692613'],
#  ['EPAMB022', '5,545,998', '5,522,145', '99.5699060836'],
#  ['EPWIS002', '5,501,324', '5,453,804', '99.1362079383'],
#  ['KPVP019', '5,488,758', '5,467,654', '99.6155050013'],
#  ['KPMQ043', '5,482,517', '5,372,827', '97.9992766096'],
#  ['EPDDU029', '5,451,627', '5,406,128', '99.1654051167'],
#  ['EPAMB018', '5,440,945', '5,414,126', '99.5070893016'],
#  ['EPAMB002', '5,429,658', '5,403,549', '99.5191409846'],
#  ['EPFLD016', '5,424,100', '5,386,490', '99.3066130787'],
#  ['KPVP013', '5,297,045', '5,276,016', '99.6030050717'],
#  ['KPMQ021', '5,264,423', '5,205,579', '98.8822326777'],
#  ['EPWIS008', '5,199,573', '5,163,229', '99.301019526'],
#  ['EPCWS002', '5,173,222', '5,147,477', '99.5023410942'],
#  ['EPAUS023', '5,156,050', '5,130,009', '99.4949428341'],
#  ['EPCWA002', '5,079,869', '5,044,947', '99.3125413273'],
#  ['KPUVF010', '5,055,376', '5,033,567', '99.5685978649'],
#  ['KPUVF011', '5,044,496', '5,022,781', '99.5695308312'],
#  ['EPAUS020', '4,948,755', '4,922,576', '99.4709982612'],
#  ['EPWIS013', '4,934,354', '4,900,713', '99.3182288908'],
#  ['KPVP005', '4,910,077', '4,875,784', '99.3015791809'],
#  ['KPVP003', '4,882,692', '4,847,967', '99.2888144491'],
#  ['EPFLD004', '4,790,605', '4,758,764', '99.3353449095'],
#  ['KPVP001', '4,784,559', '4,749,225', '99.2614993357'],
#  ['EPAUS004', '4,773,115', '4,749,286', '99.5007662711'],
#  ['EPAMB007', '4,766,394', '4,744,181', '99.5339663486'],
#  ['EPGOU033', '4,749,831', '4,716,997', '99.3087333002'],
#  ['EPAMB006', '4,666,094', '4,645,845', '99.566039604'],
#  ['KPFORT011', '4,567,441', '4,548,765', '99.5911058293'],
#  ['EPGOU030', '4,557,366', '4,527,294', '99.3401451628'],
#  ['KPVP017', '4,535,868', '4,518,091', '99.6080794238'],
#  ['EPCWB004', '4,457,306', '4,435,489', '99.5105339414'],
#  ['KPFORT010', '4,422,327', '4,403,361', '99.5711307644'],
#  ['EPAUS022', '4,411,586', '4,389,245', '99.4935834868'],
#  ['EPAMB016', '4,402,566', '4,384,070', '99.5798813692'],
#  ['EPCRD001', '4,335,292', '4,301,937', '99.2306169919'],
#  ['EPGOU034', '4,291,889', '4,264,280', '99.356716821'],
#  ['KPMQ034', '4,283,046', '4,234,887', '98.8755899423'],
#  ['EPFLD001', '4,214,128', '4,185,680', '99.3249374485'],
#  ['KPFORT016', '4,192,855', '4,176,898', '99.6194239963'],
#  ['KPMQ042', '4,179,579', '4,121,432', '98.6087833248'],
#  ['EPFLD014', '4,142,558', '4,116,446', '99.3696648303'],
#  ['KPFORT023', '4,135,246', '4,115,699', '99.5273074443'],
#  ['EPAUS027', '4,048,755', '4,030,612', '99.5518869381'],
#  ['KPMQ020', '3,999,789', '3,959,746', '98.9988721905'],
#  ['EPCRD007', '3,962,724', '3,929,349', '99.1577763175'],
#  ['EPFLD028', '3,950,363', '3,924,130', '99.3359344445'],
#  ['EPAUS010', '3,944,460', '3,924,290', '99.4886499039'],
#  ['EPDDU010', '3,944,090', '3,917,255', '99.3196149175'],
#  ['EPWIS007', '3,934,888', '3,908,370', '99.3260799291'],
#  ['EPFLD015', '3,896,308', '3,870,449', '99.3363204346'],
#  ['EPGOU045', '3,869,974', '3,841,785', '99.2715971735'],
#  ['KPFORT019', '3,851,758', '3,835,216', '99.5705337667'],
#  ['EPCWA006', '3,840,489', '3,820,685', '99.4843364999'],
#  ['EPAUS025', '3,812,431', '3,796,047', '99.5702479599'],
#  ['KPVP018', '3,763,554', '3,750,110', '99.6427844532'],
#  ['EPGOU040', '3,756,852', '3,729,040', '99.259699344'],
#  ['EPAUS018', '3,649,298', '3,627,793', '99.4107085801'],
#  ['EPAMB019', '3,624,939', '3,607,099', '99.5078537873'],
#  ['EPAMB014', '3,612,803', '3,596,565', '99.5505428887'],
#  ['EPGOU035', '3,602,617', '3,579,062', '99.3461697427'],
#  ['EPWIS009', '3,488,508', '3,463,759', '99.2905563066'],
#  ['EPCRD002', '3,446,453', '3,414,037', '99.0594387911'],
#  ['EPGOU043', '3,436,384', '3,412,045', '99.2917264194'],
#  ['EPGOU044', '3,422,592', '3,397,757', '99.2743803527'],
#  ['EPGOU031', '3,414,121', '3,392,522', '99.3673627853'],
#  ['EPCRD004', '3,386,823', '3,363,967', '99.3251492623'],
#  ['EPAMB013', '3,381,744', '3,365,164', '99.5097204283'],
#  ['EPGOU041', '3,359,506', '3,334,816', '99.2650705193'],
#  ['EPAMB029', '3,328,405', '3,313,444', '99.5505054223'],
#  ['EPGOU038', '3,208,600', '3,184,533', '99.2499220844'],
#  ['KPVP009', '3,192,619', '3,180,578', '99.6228488272'],
#  ['EPCWC014', '3,105,151', '3,089,652', '99.5008616328'],
#  ['EPCRD019', '3,095,907', '3,072,088', '99.2306293438'],
#  ['EPAMB010', '3,066,763', '3,053,400', '99.5642636878'],
#  ['EPAMB020', '3,056,387', '3,041,802', '99.522802577'],
#  ['EPGOU039', '3,001,854', '2,979,718', '99.2625890533'],
#  ['EPGOU032', '2,963,418', '2,944,111', '99.3484888058'],
#  ['KPVP007', '2,941,645', '2,928,998', '99.5700704878'],
#  ['KPVP008', '2,898,232', '2,885,934', '99.5756723409'],
#  ['EPAUS017', '2,885,300', '2,871,381', '99.5175891588'],
#  ['KPVP006', '2,828,919', '2,817,851', '99.6087551464'],
#  ['EPAUS019', '2,760,249', '2,745,487', '99.4651931764'],
#  ['EPAMB012', '2,654,424', '2,640,763', '99.4853497407'],
#  ['EPCWA007', '2,634,728', '2,620,935', '99.4764924501'],
#  ['EPCRD008', '2,620,501', '2,602,175', '99.3006680784'],
#  ['EPWIS001', '2,553,506', '2,533,702', '99.2244388695'],
#  ['EPAUS016', '2,431,101', '2,418,834', '99.4954138063'],
#  ['EPAMB030', '2,328,322', '2,310,136', '99.2189224686'],
#  ['EPCWC050', '2,153,158', '2,141,900', '99.4771400891'],
#  ['EPAUS002', '2,130,979', '2,120,534', '99.5098496982'],
#  ['EPADF001', '2,127,876', '2,111,282', '99.2201613252'],
#  ['EPCRD020', '1,879,454', '1,866,479', '99.3096399273'],
#  ['EPCWB031', '1,821,114', '1,811,511', '99.4726854003'],
#  ['EPCRD017', '1,547,799', '1,535,174', '99.1843256133'],
#  ['EPCRD016', '593,282', '588,865', '99.2554973857'],
#  ['EPADC001', '89,016', '88,029', '98.8912105689'],
#  ['EPWIS026', '64,616', '63,223', '97.8441871982'],
#  ['EPCRD006', '51,905', '50,988', '98.2333108564'],
#  ['EPAUS015', '3,804', '3,697', '97.1871713985']]

# %%
print 'Percentage of reads kept after trimming ranges from', \
min([float(x[3]) for x in statTable[1:]]),'to',\
max([float(x[3]) for x in statTable[1:]])
# Out:
# Percentage of reads kept after triming ranges from 97.0250867998 to 99.6427844532

# %% [markdown]
# ### Mapping reads to EP genome
#
# Emperor Penguin genome (release 2011-07-06) was downloaded from:
#
#     http://gigadb.org/dataset/100005
#     ftp://climb.genomics.cn/pub/10.5524/100001_101000/100005/Aptenodytes_forsteri.scaf.fa.gz
#
# BWA was used to index the genome for mapping. BWA was then used to align to the genome:
#
#     bwa mem -t 32 Aptenodytes_forsteri.scaf.fa lib_1.fastq lib_2.fastq | samtools view -b - > lib.bam
